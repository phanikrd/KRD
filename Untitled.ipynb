# %%
import numpy as np
import pandas as pd
import matplot as mpl
import matplotlib.pyplot as plt
import json

# %%
df=pd.read_csv("C:\\Users\\impha\\Desktop\\Topic_Survey_Assignment.csv")
df
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 0   Big Data (Spark / Hadoop)             1332                  729
# 1  Data Analysis / Statistics             1688                  444
# 2             Data Journalism              429                 1081
# 3          Data Visualization             1340                  734
# 4               Deep Learning             1263                  770
# 5            Machine Learning             1629                  477
#
#    Not interested
# 0             127
# 1              60
# 2             610
# 3             102
# 4             136
# 5              74

# %%
df1=df.sort_values(by='Very interested', ascending=False)
df1
# Out:
#                    Unnamed: 0  Very interested  Somewhat interested  \
# 1  Data Analysis / Statistics             1688                  444
# 5            Machine Learning             1629                  477
# 3          Data Visualization             1340                  734
# 0   Big Data (Spark / Hadoop)             1332                  729
# 4               Deep Learning             1263                  770
# 2             Data Journalism              429                 1081
#
#    Not interested
# 1              60
# 5              74
# 3             102
# 0             127
# 4             136
# 2             610

# %%
df1.plot(kind="bar",figsize=(20,8),color = ['#5cb85c', '#5bc0de', '#d9534f'],width=0.8)
index = np.arange(6)
bar_width = 0.002

plt.xticks(index + bar_width,("Data Analysis/Statistics", "Machine Learning", "Data Visualization", "Big Data (Spark / Hadoop)","Deep Learning", "Data Journalism"))

plt.show()

# %%
df2=pd.read_csv("C:\\Users\\impha\\Downloads\\Police_Department_Incidents_-_Previous_Year__2016_.csv")
df2
# Out:
#         IncidntNum        Category  \
# 0        120058272     WEAPON LAWS
# 1        120058272     WEAPON LAWS
# 2        141059263        WARRANTS
# 3        160013662    NON-CRIMINAL
# 4        160002740    NON-CRIMINAL
# ...            ...             ...
# 150495   161061000         ASSAULT
# 150496   176000742    NON-CRIMINAL
# 150497   176000758   LARCENY/THEFT
# 150498   176000764   LARCENY/THEFT
# 150499   179002868  OTHER OFFENSES
#
#                                                  Descript DayOfWeek  \
# 0                               POSS OF PROHIBITED WEAPON    Friday
# 1          FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE    Friday
# 2                                          WARRANT ARREST    Monday
# 3                                           LOST PROPERTY   Tuesday
# 4                                           LOST PROPERTY    Friday
# ...                                                   ...       ...
# ...

# %%
df3=(df2.loc[0:150499,'PdDistrict'])
df3.describe()
# Out:
# count       150499
# unique          10
# top       SOUTHERN
# freq         28445
# Name: PdDistrict, dtype: object

# %%
df_tmp = df2.groupby(['PdDistrict']).count().reset_index()
df_tmp.drop(['Category','Descript','DayOfWeek','Date','Time', 'Resolution','Address','X','Y','Location','PdId'], axis=1, inplace=True)
df_tmp.rename(columns={'PdDistrict':'Neighborhood', 'IncidntNum':'Count'}, inplace=True)
df_tmp
# Out:
#   Neighborhood  Count
# 0      BAYVIEW  14303
# 1      CENTRAL  17666
# 2    INGLESIDE  11594
# 3      MISSION  19503
# 4     NORTHERN  20100
# 5         PARK   8699
# 6     RICHMOND   8922
# 7     SOUTHERN  28445
# 8      TARAVAL  11325
# 9   TENDERLOIN   9942

# %%
#https://cocl.us/sanfran_geojson
# !wget --quiet https://cocl.us/sanfran_geojson -O sanfran_geo.json    
print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
